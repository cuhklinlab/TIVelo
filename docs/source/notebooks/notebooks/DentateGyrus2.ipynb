# %% [markdown]
# # Dentate Gyrus development 2

# %%
import shutup
shutup.please()

import scanpy as sc
from tivelo.main import tivelo
from baseline import run_baseline
# Out:
# (Running UniTVelo 0.2.5.2)
# 2024-05-18 07:04:22

# %% [markdown]
# ## Run TIVelo
# Load the dataset. Set the data name with key for cluster, key for embedding and cluster edges (for comparison).

# %%
data_name = "dentategyrus2"
data_path = "D:/cuhk/project/velocity/dataset/scRNA-seq/DentateGyrus/DentateGyrus_processed.h5ad"
adata = sc.read(data_path)

group_key = "ClusterName"
emb_key = "X_tsne"
cluster_edges = [('nIPC', 'Nbl1'), ('nIPC', 'GlialProg'), ('GlialProg', 'ImmAstro'), ('GlialProg', 'OPC'),
                 ('Nbl1', 'RadialGlia'), ('RadialGlia', 'RadialGlia2'), ('Nbl1', 'Nbl2'), 
                 ('Nbl2', 'ImmGranule1'), ('ImmGranule1', 'ImmGranule2'), ('ImmGranule2', 'Granule'), 
                 ('Nbl2', 'CA'), ('CA', 'CA1-Sub'), ('CA', 'CA2-3-4')]

# %% [markdown]
# Set the model parameters.

# %%
save_folder = "results"
show_fig = True
filter_genes = True
save_coeff = True
constrain = True
loss_fun = "mse"
only_s = False
alpha_1 = 1
alpha_2 = 0.1
batch_size = 1024
n_epochs = 100

tree_gene = None
show_DTI = False
adjust_DTI = False
velocity_key = "velocity"
measure_performance = True

# %% [markdown]
# Run the model by function tivelo.

# %%
adata_ = tivelo(adata, group_key, emb_key, data_name=data_name, save_folder=save_folder, njobs=-1, tree_gene=tree_gene,
                show_fig=show_fig, filter_genes=filter_genes, constrain=constrain, loss_fun=loss_fun, only_s=only_s,
                alpha_1=alpha_1, alpha_2=alpha_2, batch_size=batch_size, n_epochs=n_epochs, velocity_key="velocity",
                adjust_DTI=adjust_DTI, show_DTI=show_DTI, cluster_edges=cluster_edges,
                measure_performance=measure_performance)
# Out:
# computing velocities
#     finished (0:00:05) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 20/20 cores)
#   0%|          | 0/18213 [00:00<?, ?cells/s]
#     finished (0:00:39) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing terminal states
#     identified 3 regions of root cells and 4 regions of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# 'path_dict' added to adata.uns
# main path: ['nIPC', 'Nbl1', 'Nbl2', 'ImmGranule1', 'ImmGranule2', 'Granule']
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   55.6s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 760 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 801 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 842 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 885 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 928 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 973 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 1018 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 1065 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 1112 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 1178 out of 1178 | elapsed:  9.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# mean: 9.082
# median: 4.660
# lower quantile: -14.732
# upper quantile: 30.285
# minimum: -259.528
# maximum: 637.525
# No. of positive scores: 676
#
# branch_1: ['Nbl1', 'GlialProg', 'OPC']
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.17940020561218262s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 722 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 780 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 842 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 904 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 970 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 1036 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 1106 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 1178 out of 1178 | elapsed:   13.1s finished
# mean: 1.626
# median: 1.827
# lower quantile: -16.587
# upper quantile: 21.077
# minimum: -241.867
# maximum: 191.040
# No. of positive scores: 619
#
# branch_2: ['Nbl1', 'RadialGlia', 'RadialGlia2', 'ImmAstro']
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed:   56.5s
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 760 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 801 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 842 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 885 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 928 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 973 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 1018 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 1065 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 1112 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 1178 out of 1178 | elapsed:  1.8min finished
# mean: 3.650
# median: 3.073
# lower quantile: -13.136
# upper quantile: 19.914
# minimum: -270.524
# maximum: 177.755
# No. of positive scores: 650
#
# branch_3: ['Nbl2', 'CA', 'CA2-3-4']
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:   52.2s
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 760 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 801 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 842 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 885 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 928 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 973 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 1018 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 1065 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 1112 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 1178 out of 1178 | elapsed:  4.0min finished
# mean: 4.822
# median: 2.143
# lower quantile: -19.545
# upper quantile: 24.543
# minimum: -211.623
# maximum: 429.286
# No. of positive scores: 619
#
# 'path_dict' added to adata.uns
# 'child_dict' added to adata.uns
# 'level_dict' added to adata.uns
# 'threshold_list' added to adata.uns
# 'd_nn' added to adata.obsp
# Model training: 100%|██████████| 100/100 [11:56<00:00,  7.17s/it, cos_s=0.652, cos_u=0.803, mse_s=0.009, mse_u=0.009]
# computing velocity graph (using 20/20 cores)
#   0%|          | 0/18213 [00:00<?, ?cells/s]
#     finished (0:00:38) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:02) --> added
#     'velocity_tsne', embedded velocity vectors (adata.obsm)
# TIVelo:
#  CBDir: 0.6401 ICVCoh: 0.6563
#  CBDir2: 0.4265 ICVCoh2: 0.8424
#  TransProbs: 0.3742 VeloCoh: 0.1552

# %% [markdown]
# ## Run scVelo
# Stochastic mode.

# %%
adata_scvelo = run_baseline(adata, "scvelo", data_name, group_key, emb_key, cluster_edges, show_fig=True,
                            measure_performance=True)
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_tsne', embedded velocity vectors (adata.obsm)
# scvelo:
#  CBDir: 0.2936 ICVCoh: 0.8956
#  CBDir2: 0.0220 ICVCoh2: 0.7645
#  TransProbs: 0.1443 VeloCoh: 0.0416

# %% [markdown]
# Dynamical mode.

# %%
adata_scvelo2 = run_baseline(adata, "scvelo2", data_name, group_key, emb_key, cluster_edges, show_fig=True,
                            measure_performance=True)
# Out:
# scvelo2:
#  CBDir: 0.1602 ICVCoh: 0.9059
#  CBDir2: 0.0381 ICVCoh2: 0.6840
#  TransProbs: 0.2185 VeloCoh: 0.1222

# %% [markdown]
# ## Run veloVI.

# %%
adata_velovi = run_baseline(adata, "velovi", data_name, group_key, emb_key, cluster_edges, show_fig=True,
                            measure_performance=True)
# Out:
# velovi:
#  CBDir: 0.3826 ICVCoh: 0.9153
#  CBDir2: 0.0408 ICVCoh2: 0.8038
#  TransProbs: 0.0512 VeloCoh: 0.1129

# %% [markdown]
# ## Run UniTVelo.

# %%
adata_unitvelo = run_baseline(adata, "unitvelo", data_name, group_key, emb_key, cluster_edges, show_fig=True,
                              measure_performance=True)
# Out:
# unitvelo:
#  CBDir: 0.3333 ICVCoh: 0.9899
#  CBDir2: 0.0514 ICVCoh2: 0.8925
#  TransProbs: 0.0932 VeloCoh: -0.0604

# %% [markdown]
# ## Run cellDancer

# %%
adata_celldancer = run_baseline(adata, "celldancer", data_name, group_key, emb_key, cluster_edges, show_fig=True,
                                measure_performance=True)
# Out:
# computing velocity graph (using 20/20 cores)
#   0%|          | 0/18213 [00:00<?, ?cells/s]
#     finished (0:00:07) --> added
#     'velocity_S_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_S_tsne', embedded velocity vectors (adata.obsm)
# celldancer:
#  CBDir: 0.0558 ICVCoh: 0.9502
#  CBDir2: 0.0404 ICVCoh2: 0.5486
#  TransProbs: 0.0001 VeloCoh: -0.1316
