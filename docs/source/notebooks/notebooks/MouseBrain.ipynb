# %% [markdown]
# #  Embryonic mouse brain

# %%
import shutup
shutup.please()

import scanpy as sc
from tivelo.main import tivelo
from baseline import run_baseline
# Out:
# (Running UniTVelo 0.2.5.2)
# 2024-05-18 08:53:51

# %% [markdown]
# ## Run TIVelo
# Load the dataset. Set the data name with key for cluster, key for embedding and cluster edges (for comparison).

# %%
data_name = "MouseBrain"
rna_path = "D:/cuhk/project/velocity/dataset/atac/MouseBrain/adata_rna.h5ad"
atac_path = "D:/cuhk/project/velocity/dataset/atac/MouseBrain/adata_atac.h5ad"
adata = sc.read(rna_path)
adata_atac = sc.read(atac_path)

group_key = "celltype"
emb_key = "X_umap"
cluster_edges = [('RG, Astro, OPC', 'IPC'), ('IPC', 'V-SVZ'), ('V-SVZ', 'Upper layer'), ('Upper layer', 'Deeper layer')]

# %% [markdown]
# Set the model parameters.

# %%
save_folder = "results"
show_fig = True
filter_genes = True
save_coeff = True
constrain = True
loss_fun = "mse"
only_s = False
alpha_1 = 1
alpha_2 = 0.1
batch_size = 1024
n_epochs = 100

tree_gene = None
show_DTI = False
adjust_DTI = False
velocity_key = "velocity"
measure_performance = True

# %% [markdown]
# Run the model by function tivelo.

# %%
adata_ = tivelo(adata, group_key, emb_key, data_name=data_name, save_folder=save_folder, njobs=-1, tree_gene=tree_gene,
                show_fig=show_fig, filter_genes=filter_genes, constrain=constrain, loss_fun=loss_fun, only_s=only_s,
                alpha_1=alpha_1, alpha_2=alpha_2, batch_size=batch_size, n_epochs=n_epochs, velocity_key="velocity",
                adjust_DTI=adjust_DTI, show_DTI=show_DTI, cluster_edges=cluster_edges,
                measure_performance=measure_performance)
# Out:
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 20/20 cores)
#   0%|          | 0/3365 [00:00<?, ?cells/s]
#     finished (0:00:15) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing terminal states
#     identified 1 region of root cells and 1 region of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# 'path_dict' added to adata.uns
# main path: ['RG, Astro, OPC', 'IPC', 'Ependymal cells', 'Subplate', 'Upper Layer']
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 737 out of 737 | elapsed:   24.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07711982727050781s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.0s
# mean: 4.170
# median: 2.088
# lower quantile: -16.577
# upper quantile: 21.040
# minimum: -144.435
# maximum: 173.094
# No. of positive scores: 391
#
# branch_1: ['IPC', 'V-SVZ']
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 698 out of 737 | elapsed:    3.6s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 737 out of 737 | elapsed:    3.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07406067848205566s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.1s
# mean: -0.074
# median: 0.834
# lower quantile: -20.016
# upper quantile: 21.312
# minimum: -298.926
# maximum: 217.393
# No. of positive scores: 381
#
# branch_2: ['Subplate', 'Deeper Layer']
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 698 out of 737 | elapsed:    3.9s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 737 out of 737 | elapsed:    4.0s finished
# mean: 0.933
# median: 0.805
# lower quantile: -10.722
# upper quantile: 12.852
# minimum: -225.421
# maximum: 216.083
# No. of positive scores: 383
#
# 'path_dict' added to adata.uns
# 'child_dict' added to adata.uns
# 'level_dict' added to adata.uns
# 'threshold_list' added to adata.uns
# 'd_nn' added to adata.obsp
# Model training: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s, cos_s=0.646, cos_u=0.535, mse_s=0.006, mse_u=0.002]
# computing velocity graph (using 20/20 cores)
#   0%|          | 0/3365 [00:00<?, ?cells/s]
#     finished (0:00:05) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# TIVelo:
#  CBDir: 0.4893 ICVCoh: 0.6698
#  CBDir2: 0.6415 ICVCoh2: 0.8240
#  TransProbs: 0.5854 VeloCoh: 0.3288

# %% [markdown]
# ## Run MultiVelo.

# %%
adata_multivelo = run_baseline(adata, "multivelo", data_name, group_key, emb_key, cluster_edges, 
                               adata_atac=adata_atac, show_fig=True, measure_performance=True)
# Out:
# multivelo:
#  CBDir: -0.0780 ICVCoh: 0.8545
#  CBDir2: -0.0028 ICVCoh2: 0.8224
#  TransProbs: 0.0338 VeloCoh: 0.0409
